# %% [markdown]
# # MDS Handout 2 — Introduction to Machine Learning
#
# ## Bài 1 — Tôi Hiểu ML Là Gì?
#
# ### Bài 1.1 — Hai định nghĩa, một ý nghĩa
#
# #### a. Từ quan trọng nhất trong định nghĩa Samuel?
#
# **Trả lời:**
#
# Từ quan trọng nhất là **"learn" (học)** vì Machine Learning cho phép máy tính học từ dữ liệu thay vì phải viết toàn bộ rules thủ công.
#
# ---
#
# #### b. Viết lại định nghĩa ML bằng ngôn ngữ của bạn
#
# **Trả lời:**
#
# Machine Learning là phương pháp giúp máy tính học từ dữ liệu để cải thiện khả năng dự đoán hoặc ra quyết định mà không cần lập trình chi tiết từng bước.
#
# ---
#
# ## Bài 1.2 — T.E.P Framework
#
# #### Điền vào bảng T.E.P. cho 3 ứng dụng ML sau:
#
#
# | Ứng dụng              | Task (T)                 | Experience (E)         | Performance (P)     |
# | --------------------- | ------------------------ | ---------------------- | ------------------- |
# | Spam Filter           | Phân loại email spam/ham | Email đã được gán nhãn | Accuracy, Precision |
# | Netflix gợi ý phim    | Gợi ý phim phù hợp       | Lịch sử xem phim       | Tỷ lệ click/watch   |
# | Shopee gợi ý sản phẩm | Đề xuất sản phẩm         | Lịch sử mua hàng       | Conversion rate     |
#
# ---
#
# ## Bài 1.3 — Suy nghĩ phản biện
#
# #### Bài toán: 'Viết chương trình dự đoán nhiệt độ ngày mai.' Bạn sẽ dùng ML hay Traditional Programming? Tại sao?
#
#
# **Trả lời:**
#
# Dùng Machine Learning vì dự đoán nhiệt độ phụ thuộc nhiều yếu tố phức tạp như độ ẩm, gió, áp suất,... rất khó viết rules thủ công.
#
# ---
#
# # Bài 2 — ML Giỏi Hơn Ở Đâu?
#
# ## Bài 2.1 — Điền bảng so sánh
#
# | Tiêu chí              | Traditional Programming | Machine Learning |
# | --------------------- | ----------------------- | ---------------- |
# | Cách giải quyết       | Người viết rules        | Học từ dữ liệu   |
# | Khi bài toán thay đổi | Phải sửa rules          | Retrain model    |
# | Dataset lớn           | Khó xử lý               | Xử lý tốt hơn    |
# | Explainability        | Cao                     | Thấp hơn         |
# | Thời gian xây dựng    | Nhanh với bài đơn giản  | Cần nhiều data   |
#
# ---
#
# ## Bài 2.2 — Phân loại ứng dụng
#
# #### Phân loại 8 ứng dụng sau vào đúng nhóm (Vision / NLP / Analytics / Other):
#
# | Ứng dụng                | Nhóm         | Learning        |
# | ----------------------- | ------------ | --------------- |
# | Face unlock             | Vision       | Supervised      |
# | Google Translate        | NLP          | Supervised      |
# | Netflix gợi ý phim      | Analytics    | Supervised      |
# | Fraud detection         | Analytics    | Supervised      |
# | ChatGPT                 | NLP          | Semi-supervised |
# | Xe tự lái               | Vision/Other | Reinforcement   |
# | Spotify Discover Weekly | Analytics    | Supervised      |
# | Dự đoán giá cổ phiếu    | Analytics    | Regression      |
#
# ---
#
# ## Bài 2.3 — ML Ethics
#
# #### Amazon đã build hệ thống ML để sàng lọc CV tuyển dụng — và phải bỏ đi vì nó bị bias với CV của phụ nữ. Hệ thống đã học từ CV lịch sử (toàn nam giới) và 'học' rằng nam giới tốt hơn.
#
# ### a. Nguyên nhân gốc rễ
#
# Dữ liệu training bị bias vì dữ liệu lịch sử chủ yếu là CV nam giới.
#
# ### b. Cách ngăn chặn bias
#
# Kiểm tra fairness, cân bằng dữ liệu và đánh giá model trên nhiều nhóm khác nhau.
#
# ### c. Có nên dùng ML trong tuyển dụng?
#
# Có thể dùng để hỗ trợ nhưng không nên quyết định hoàn toàn.
#
# ---
#
# # Bài 3 — Phân Loại Các Bài Toán ML
#
# ## Bài 3.1 — Điền vào bảng tóm tắt 4 loại learning
#
# | Loại Learning   | Đặc điểm                   | Label?   | Ví dụ                 | Thuật toán      |
# | --------------- | -------------------------- | -------- | --------------------- | --------------- |
# | Supervised      | Học từ dữ liệu có nhãn     | Có       | Spam detection        | SVM             |
# | Unsupervised    | Tự tìm patterns            | Không    | Customer segmentation | K-Means         |
# | Semi-supervised | Ít label + nhiều unlabeled | Một phần | Speech recognition    | Pseudo-labeling |
# | Reinforcement   | Học qua reward             | Reward   | Game AI               | Q-Learning      |
#
# ---
#
# ## Bài 3.2 — Classification vs Regression
#
# #### Với mỗi bài toán, xác định là Classification (C) hay Regression (R) và giải thích:
#
# | Bài toán            | C/R            | Lý do            |
# | ------------------- | -------------- | ---------------- |
# | Dự đoán giá nhà     | Regression     | Output là số     |
# | Spam email          | Classification | Output là nhãn   |
# | Dự đoán điểm thi    | Regression     | Giá trị liên tục |
# | Chẩn đoán bệnh      | Classification | Phân loại        |
# | Dự đoán số hàng bán | Regression     | Giá trị số       |
# | Nhận diện chữ số    | Classification | Phân loại 0-9    |
#
# ---
#
# ## Bài 3.3 — Phân loại bài toán
#
# #### Với mỗi bài toán, nhóm phân loại vào: Supervised / Unsupervised / Semi-supervised / Reinforcement. Giải thích lý do.
#
#
# | Bài toán                 | Learning        | Lý do                |
# | ------------------------ | --------------- | -------------------- |
# | Robot chơi cờ vua        | Reinforcement   | Có reward            |
# | Phân nhóm ảnh            | Unsupervised    | Không có label       |
# | Dự đoán SV bỏ học        | Supervised      | Có dữ liệu lịch sử   |
# | Speech recognition       | Semi-supervised | Có ít label          |
# | Gợi ý sản phẩm           | Supervised      | Dựa lịch sử mua hàng |
# | Phát hiện bất thường log | Unsupervised    | Tìm anomaly          |
# | Dịch Anh-Việt            | Supervised      | Có cặp câu           |
# | AlphaGo                  | Reinforcement   | Học qua reward       |
#
# ---
#
# # Bài 4 — Chẩn Đoán Vấn Đề ML
#
# ## Bài 4.1 — Vấn đề data
#
# #### Ghép nối từng mô tả với loại data problem (mỗi loại dùng 1 lần):
#
# | Tình huống                 | Data Problem           |
# | -------------------------- | ---------------------- |
# | Chỉ có nhân viên văn phòng | Nonrepresentative Data |
# | Tuổi = 999                 | Poor Quality           |
# | Chỉ có 50 ảnh              | Insufficient Quantity  |
# | Mã màu không liên quan     | Irrelevant Features    |
# | Không nhận giọng miền Nam  | Sampling Bias          |
#
# ---
#
# ## Bài 4.2 — Overfitting vs Underfitting
#
# | Scenario | Chẩn đoán        | Giải pháp              |
# | -------- | ---------------- | ---------------------- |
# | A        | Overfitting      | Giảm độ phức tạp model |
# | B        | Underfitting     | Tăng độ phức tạp model |
# | C        | Tốt              | Giữ nguyên             |
# | D        | Underfitting nhẹ | Thêm feature           |
# | E        | Rất tốt          | Có thể deploy          |
#
# ---
#
# ## Bài 4.3 — Quan sát overfitting

# %%
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
# Tạo dataset đơn giản
X, y = make_classification(n_samples=200, n_features=10, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# Thử các độ sâu khác nhau
for depth in [1, 2, 3, 5, 10, None]: # None = không giới hạn
 model = DecisionTreeClassifier(max_depth=depth, random_state=42)
 model.fit(X_train, y_train)
 train_acc = model.score(X_train, y_train)
 test_acc = model.score(X_test, y_test)
 print(f'depth={depth}: train={train_acc:.3f}, test={test_acc:.3f}')
# Out:
# depth=1: train=0.879, test=0.900
# depth=2: train=0.893, test=0.900
# depth=3: train=0.936, test=0.900
# depth=5: train=0.950, test=0.917
# depth=10: train=1.000, test=0.883
# depth=None: train=1.000, test=0.883

# %% [markdown]
# ### Quan sát: Khi depth tăng, train accuracy và test accuracy thay đổi như thế nào?
#
# Khi depth tăng, train accuracy tăng mạnh nhưng test accuracy sau một mức sẽ giảm do overfitting.
#
# ### Depth nào gây overfitting rõ nhất? Bạn nhận ra bằng dấu hiệu gì?
#
# Depth = None gây overfitting rõ nhất.
#
# ### Bạn sẽ chọn depth nào để deploy? Tại sao?
#
# Depth khoảng 3 hoặc 5 vì cân bằng train/test accuracy.
#
# ---
#
# # Bài 5 — Testing & Validation
#
# ## Bài 5.1 — Train/Validation/Test
#
# #### Bạn có 10,000 dòng data. Thiết kế chiến lược split và giải thích:
#
# | Split      | Tỷ lệ | Mục đích      |
# | ---------- | ----- | ------------- |
# | Training   | 70%   | Train model   |
# | Validation | 15%   | Tune model    |
# | Test       | 15%   | Đánh giá cuối |
#
# ### Vì sao không được nhìn vào Test Set khi đang tune model?
#
# Vì sẽ gây data leakage và đánh giá model không còn khách quan.
#
# ---
#
# ## Bài 5.2 — K-Fold Cross Validation
#
# ### Mô tả bằng hình vẽ hoặc chữ: K-Fold (K=5) hoạt động như thế nào?
#
# ####  Sơ đồ K=5 Cross-Validation (vẽ hoặc mô tả):
#
# K=5 nghĩa là chia dataset thành 5 phần, mỗi lần dùng 1 phần validation và 4 phần training.
#
# #### Kết quả cuối cùng của K-Fold là gì? Tại sao tốt hơn dùng 1 validation set?
#
# Là trung bình accuracy của 5 lần chạy.
#
# ---
#
# ## Bài 5.3 — ML vs Statistical Modeling
#
# | Tiêu chí       | Statistical Modeling | Machine Learning |
# | -------------- | -------------------- | ---------------- |
# | Mục tiêu       | Giải thích           | Dự đoán          |
# | Dữ liệu        | Ít hơn               | Nhiều hơn        |
# | Explainability | Cao                  | Thấp hơn         |
# | Ví dụ          | Linear Regression    | Random Forest    |
#
# ### Phân loại bài toán
#
# #### Bài toán nào sau đây phù hợp hơn với ML? Với Stats? Với cả hai? a. 'Thu nhập có ảnh hưởng đến tỉ lệ mua hàng không?' b. 'Dự đoán khách hàng nào có khả năng mua cao nhất' c. 'Yếu tố nào giúp sinh viên tốt nghiệp đúng hạn?'
#
# * Thu nhập ảnh hưởng mua hàng → Statistical Modeling
# * Dự đoán khách hàng mua → Machine Learning
# * Yếu tố giúp SV tốt nghiệp → Cả hai
#
# ---
#
# # Bài 6 — Dự Án Cá Nhân
#
# ## 6.1 — Chọn bài toán ML của bạn
#
# #### Gợi ý lĩnh vực: Tài chính / Y tế / Giáo dục / E-commerce / Thể thao / Môi trường / Mạng xã hội / Giao thông
#
# ### Bài toán
#
# Dự đoán sinh viên có nguy cơ rớt môn.
#
# ### Impact
#
# Giúp hỗ trợ sinh viên sớm hơn và cải thiện kết quả học tập.
#
# ---
#
# ## 6.2 — T.E.P cho dự án
#
# | Thành phần  | Nội dung            |
# | ----------- | ------------------- |
# | Task        | Dự đoán SV rớt môn  |
# | Experience  | Điểm số, chuyên cần |
# | Performance | Accuracy > 85%      |
#
# ---
#
# ## 6.3 — Phân tích bài toán
#
# | Câu hỏi                       | Trả lời                    |
# | ----------------------------- | -------------------------- |
# | Loại learning                 | Supervised                 |
# | Classification hay Regression | Classification             |
# | Data lấy từ đâu               | Kaggle/API                 |
# | Thách thức lớn nhất           | Thiếu dữ liệu sạch         |
# | 80% accuracy có ổn không      | Phụ thuộc yêu cầu bài toán |
